# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_turismo = pd.read_csv("base_microdatos.csv")

# %%
df_turismo.head(5)
# Out:
#   indice_tiempo clasificacion_vuelo clase_vuelo              aerolinea  \
# 0    2020-01-01            Cabotaje     Regular  Aerolíneas Argentinas
# 1    2020-01-01            Cabotaje     Regular  Aerolíneas Argentinas
# 2    2020-01-01            Cabotaje     Regular  Aerolíneas Argentinas
# 3    2020-01-01            Cabotaje     Regular  Aerolíneas Argentinas
# 4    2020-01-01            Cabotaje     Regular  Aerolíneas Argentinas
#
#   origen_oaci                   origen_aeropuerto origen_localidad  \
# 0        SAEZ  Aeropuerto Int. Ministro Pistarini           Ezeiza
# 1        SAEZ  Aeropuerto Int. Ministro Pistarini           Ezeiza
# 2        SAEZ  Aeropuerto Int. Ministro Pistarini           Ezeiza
# 3        SAEZ  Aeropuerto Int. Ministro Pistarini           Ezeiza
# 4        SAEZ  Aeropuerto Int. Ministro Pistarini           Ezeiza
#
#   origen_provincia origen_pais origen_continente destino_oaci  \
# 0     Buenos Aires   Argentina   América del Sur         SACO
# ...

# %%
df_turismo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   indice_tiempo        5 non-null      object
#  1   clasificacion_vuelo  5 non-null      object
#  2   clase_vuelo          5 non-null      object
#  3   aerolinea            5 non-null      object
#  4   origen_oaci          5 non-null      object
#  5   origen_aeropuerto    5 non-null      object
#  6   origen_localidad     5 non-null      object
#  7   origen_provincia     5 non-null      object
#  8   origen_pais          5 non-null      object
#  9   origen_continente    5 non-null      object
#  10  destino_oaci         5 non-null      object
#  11  destino_aeropuerto   5 non-null      object
#  12  destino_localidad    5 non-null      object
#  13  destino_provincia    5 non-null      object
#  14  destino_pais         5 non-null      object
# ...
